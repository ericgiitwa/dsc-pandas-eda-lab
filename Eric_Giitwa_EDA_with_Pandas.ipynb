# %% [markdown]
# # EDA with Pandas - Cumulative Lab
#
# ## Introduction
#
# In this section, you've learned a lot about importing, cleaning up, analyzing (using descriptive statistics) and visualizing data. In this cumulative lab, you'll get a chance to practice all of these skills with the Ames Housing dataset, which contains information about home sales in Ames, Iowa between 2006 and 2010.
#
# ## Objectives
#
# You will be able to:
#
# * Practice loading data with pandas
# * Practice calculating measures of centrality and dispersion with pandas
# * Practice creating subsets of data with pandas
# * Practice using data visualizations to explore data, and interpreting those visualizations
# * Perform a full exploratory data analysis process to gain insight about a dataset

# %% [markdown]
# ## Your Task: Explore the Ames Housing Dataset with Pandas
#
# ![aerial photo of a neighborhood](images/neighborhood_aerial.jpg)
#
# Photo by <a href="https://unsplash.com/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Matt Donders</a> on <a href="/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
#
# Each record (row) in this dataset represents a home that was sold in Ames, IA.
#
# Each feature (column) in this dataset is some attribute of that home sale. You can view the file `data/data_description.txt` in this repository for a full explanation of all variables in this dataset — 80 columns in total.
#
# We are going to focus on the following features:
#
# **SalePrice**: `Sale price of the house in dollars`
#
# **TotRmsAbvGrd**: `Total rooms above grade (does not include bathrooms)`
#
# **OverallCond**: `Rates the overall condition of the house`
# ```
#        10	Very Excellent
#        9	 Excellent
#        8	 Very Good
#        7	 Good
#        6	 Above Average
#        5	 Average
#        4	 Below Average
#        3	 Fair
#        2	 Poor
#        1	 Very Poor
# ```
#
# **YrSold**: `Year Sold (YYYY)`
#
# **YearBuilt**: `Original construction date`
#
# **LandSlope**: `Slope of property`
# ```
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
# ```

# %%
#checking the files related tot the data set
# !LS
# Out:
# CONTRIBUTING.md
# Eric_Giitwa_project_1.ipynb
# LICENSE.md
# README.md
# data
# env
# images
# splitter.py

# %% [markdown]
# ## 1. Load the Dataset with Pandas
#
# In the cell below, import:
# * `pandas` with the standard alias `pd`
# * `matplotlib.pyplot` with the standard alias `plt`
#
# And set `%matplotlib inline` so the graphs will display immediately below the cell that creates them.

# %%
# Your code here
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Now, use pandas to open the file located at `data/ames.csv` ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)). Specify the argument `index_col=0` in order to avoid creating an extra `Id` column. Name the resulting dataframe `df`.

# %%
# Your code here
#extracting the ames file
df = pd.read_csv('data/ames.csv',index_col=0 )
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %% [markdown]
# The following code checks that you loaded the data correctly:

# %%
# Run this cell without changes

# Check that df is a dataframe
assert type(df) == pd.DataFrame

# Check that there are the correct number of rows
assert df.shape[0] == 1460

# Check that there are the correct number of columns
# (if this crashes, make sure you specified `index_col=0`)
assert df.shape[1] == 80

# %% [markdown]
# Inspect the contents of the dataframe:

# %%
# Run this cell without changes
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# Run this cell without changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ## 2. Explore Data Distributions
#
# Write code to produce histograms showing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# Each histogram should have appropriate title and axes labels, as well as a black vertical line indicating the mean of the dataset. See the documentation for [plotting histograms](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html), [customizing axes](https://matplotlib.org/stable/api/axes_api.html#axis-labels-title-and-legend), and [plotting vertical lines](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html#matplotlib.axes.Axes.axvline) as needed.

# %% [markdown]
# ### Sale Price
#
# In the cell below, produce a histogram for `SalePrice`.

# %%
# Your code here
#plotting the histogram
plt.hist(df['SalePrice'], bins = 50)
#adding lables and naming the axis
plt.ylabel('Number of houses')
plt.xlabel('sale price ($)')
plt.title('Sales Price vs number of houses')
plt.show();

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
#rounding to make the dataset look more presentable
saleprice_mean = df['SalePrice'].mean().round(0)
saleprice_median = df['SalePrice'].median().round(0)
saleprice_standard_deviation = df['SalePrice'].std().round(0)

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
print(f"The houses are being sold at an average of, {saleprice_mean} $,where as most of the houses sold {saleprice_standard_deviation} $ above or below the average price, , while 50% of the houses are being sold above,{saleprice_median},$")
# Out:
# The houses are being sold at an average of, 180921.0 $,where as most of the houses sold 79443.0 $ above or below the average price, , while 50% of the houses are being sold above,163000.0,$

# %% [markdown]
# ### Total Rooms Above Grade
#
# In the cell below, produce a histogram for `TotRmsAbvGrd`.

# %%
# Your code here
plt.hist(df['TotRmsAbvGrd'], bins = 10)
plt.xlabel('Total rooms above grade')
plt.ylabel('Number of houses')
plt.title('Total rooms above grade vs Number of houses')
plt.show();

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
#rounding the data set to make it more visually appealing
TotRmsAbvGrd_mean = df['TotRmsAbvGrd'].mean().round(0)
TotRmsAbvGrd_median = df['TotRmsAbvGrd'].median().round(0)
TotRmsAbvGrd_standard_deviation = df['TotRmsAbvGrd'].std().round(0)

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
print(f"there are an average of {TotRmsAbvGrd_mean} Total rooms above grade, where as there are  {TotRmsAbvGrd_standard_deviation} more or less Total rooms above grade in each house, while 50% of the houses contain more than {TotRmsAbvGrd_median} Total rooms above grade")
# Out:
# there are an average of 7.0 Total rooms above grade, where as there are  2.0 more or less Total rooms above grade in each house, while 50% of the houses contain more than 6.0 Total rooms above grade

# %% [markdown]
# ### Overall Condition
#
# In the cell below, produce a histogram for `OverallCond`.

# %%
# Plot histogram
plt.hist(df['OverallCond'], bins=9)
plt.xlabel('Overall Condition Rating of the House')
plt.ylabel('Number of Houses')
plt.title('Overall Condition vs Number of Houses')

# Add custom legend
labels = ['10 Very Excellent', '9 Excellent', '8 Very Good', '7 Good', 
    '6 Above Average', '5 Average', '4 Below Average', 
    '3 Fair', '2 Poor', '1 Very Poor']
handles = [plt.Rectangle((0,0),1,1,  edgecolor='black') for _ in labels]
plt.legend(handles, labels, title='Condition Rating')

# Show plot
plt.show()

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
OverallCond_mean = df['OverallCond'].mean().round(0)   #.round() to make the data set more visually pleasing
OverallCond_median = df['OverallCond'].median().round(0)
OverallCond_standard_deviation = df['OverallCond'].std().round(0)

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
print(f"The average overall condition of the houses is {OverallCond_mean}, with most houses being {OverallCond_standard_deviation} ratings above or below the average rating, but 50% of the houses are above the {OverallCond_median} rating score")
# Out:
# The average overall condition of the houses is 6.0, with most houses being 1.0 ratings above or below the average rating, but 50% of the houses are above the 5.0 rating score

# %% [markdown]
# ## 3. Explore Differences between Subsets
#
# As you might have noted in the previous step, the overall condition of the house seems like we should treat it as more of a categorical variable, rather than a numeric variable.
#
# One useful way to explore a categorical variable is to create subsets of the full dataset based on that categorical variable, then plot their distributions based on some other variable. Since this dataset is traditionally used for predicting the sale price of a house, let's use `SalePrice` as that other variable.
#
# In the cell below, create three variables, each of which represents a record-wise subset of `df` (meaning, it has the same columns as `df`, but only some of the rows).
#
# * `below_average_condition`: home sales where the overall condition was less than 5
# * `average_condition`: home sales where the overall condition was exactly 5
# * `above_average_condition`: home sales where the overall condition was greater than 5

# %%
# Replace None with appropriate code
below_average_condition = df[df['OverallCond'] < 5]   #using conditionals to extract the values I require to fit each criteria
average_condition = df[df['OverallCond'] == 5]
above_average_condition = df[df['OverallCond'] > 5]

# %% [markdown]
# The following code checks that you created the subsets correctly:

# %%
# Run this cell without changes

# Check that all of them still have 80 columns
assert below_average_condition.shape[1] == 80
assert average_condition.shape[1] == 80
assert above_average_condition.shape[1] == 80

# Check the numbers of rows of each subset
assert below_average_condition.shape[0] == 88
assert average_condition.shape[0] == 821
assert above_average_condition.shape[0] == 551

# %% [markdown]
# The following code will produce a plot of the distributions of sale price for each of these subsets:

# %%
# Run this cell without changes

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Create custom bins so all are on the same scale
bins = range(df["SalePrice"].min(), df["SalePrice"].max(), int(df["SalePrice"].median()) // 20)

# Plot three histograms, with reduced opacity (alpha) so we
# can see them overlapping
ax.hist(
    x=above_average_condition["SalePrice"],
    label="above average condition",
    bins=bins,
    color="cyan",
    alpha=0.5
)
ax.hist(
    x=average_condition["SalePrice"],
    label="average condition",
    bins=bins,
    color="gray",
    alpha=0.3
)
ax.hist(
    x=below_average_condition["SalePrice"],
    label="below average condition",
    bins=bins,
    color="yellow",
    alpha=0.5
)

# Customize labels
ax.set_title("Distributions of Sale Price Grouped by Condition")
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of Houses")
ax.legend();

# %% [markdown]
# Interpret the plot above. What does it tell us about these overall condition categories, and the relationship between overall condition and sale price? Is there anything surprising?

# %%
# Replace None with appropriate text
"""
Houses in the below average condition category sell for the lowest price, with majority fo the houses being sold for less than 100000$ and are the least owned number of houses, apart from an outlier with a sale price of 400000$.
Houses in the average condition category have the largest range of prices compared to all other housing conditions with the highest price going above 700000$, which is higher than a house in the above average condition category
average condition housing has the largest number of homes at a single prce point.
shockingly houses in the above average condition do not sell at a remarkable high price point, with the highest price being just below the 500000$ mark.
it seems there is a coorelation between housing condition and sale price but not an exact causation.as the highter the housing condition did not increase the sale price significantly.
"""
# Out:
# '\nHouses in the below average condition category sell for the lowest price, with majority fo the houses being sold for less than 100000$ and are the least owned number of houses, apart from an outlier with a sale price of 400000$.\nHouses in the average condition category have the largest range of prices compared to all other housing conditions with the highest price going above 700000$, which is higher than a house in the above average condition category\naverage condition housing has the largest number of homes at a single prce point.\nshockingly houses in the above average condition do not sell at a remarkable high price point, with the highest price being just below the 500000$ mark.\nit seems there is a coorelation between housing condition and sale price but not an exact causation.as the highter the housing condition did not increase the sale price significantly.\n'

# %% [markdown]
# ## 4. Explore Correlations
#
# To understand more about what features of these homes lead to higher sale prices, let's look at some correlations. We'll return to using the full `df`, rather than the subsets.
#
# In the cell below, print out both the name of the column and the Pearson correlation for the column that is ***most positively correlated*** with `SalePrice` (other than `SalePrice`, which is perfectly correlated with itself).
#
# We'll only check the correlations with some kind of numeric data type.
#
# You can import additional libraries, although it is possible to do this just using pandas.

# %%
# Your code here
correlation = df.corr()
saleprice_correlation = correlation['SalePrice'].drop('SalePrice')
# gets the name of the column
correlated_column = saleprice_correlation.idxmax()
#gets the value associated with the column
correlated_value = saleprice_correlation.max()

print(f"Column: {correlated_column}, Pearson Correlation: {correlated_value}")
# Out:
# Column: OverallQual, Pearson Correlation: 0.7909816005838047

# %% [markdown]
# Now, find the ***most negatively correlated*** column:

# %%
# Your code here
correlation
saleprice_correlation = correlation['SalePrice'].drop('SalePrice')
negatively_correlated_column = saleprice_correlation.idxmin()
negatively_correlated_value = saleprice_correlation.min()

print(f"Column: {negatively_correlated_column}, Pearson Correlation: {negatively_correlated_value}")
# Out:
# Column: KitchenAbvGr, Pearson Correlation: -0.1359073708421417

# %% [markdown]
# Once you have your answer, edit the code below so that it produces a box plot of the relevant columns.

# %%
# Replace None with appropriate code

import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,5))

# Plot distribution of column with highest correlation
sns.boxplot(
    x=df[correlated_column],
    y=df["SalePrice"],
    ax=ax1
)
# Plot distribution of column with most negative correlation
sns.boxplot(
    x=df[negatively_correlated_column],
    y=df["SalePrice"],
    ax=ax2
)

# Customize labels
ax1.set_title('Distribution of most_correlated_column')
ax1.set_xlabel('OverallQual')
ax1.set_ylabel("Sale Price")
ax2.set_title('Distribution of most_negatively_correlated_column')
ax2.set_xlabel('KitchenAbvGr')
ax2.set_ylabel("Sale Price");

# %% [markdown]
# Interpret the results below. Consult `data/data_description.txt` as needed.

# %%
# Replace None with appropriate text
"""
houses sold with an over quality of less than 2 sold for less then 100000$ while houses with Kitchens above grade 0,2 and 3 did not sell houses above 200000$ with a shorter box plot indicating there was a smaller spread, houses did not sell well above the average price also indicated by having no outliers.
houses sold with an overall quality rating of 3 to 8 and houses with Kitchens above grade 1 increase in spread indicating houses were sold with a variability in price. although the skewness appears to be even, the sale price is evenly distributed.
houses with outliers show that some houses were sold way above the maximum value of the house indicating a larger profit margin, this is more common to houses with an overall quality of 8 and above and Kitchens above grade 0 and 3.
houses with an overall quality of 9 have a negaitve skewness indicating that the average selling price is much lower than the average while the houses with an overall quality of 10  have a possitive skewness showing that more houses were sold higher than the avrage.


"""
# Out:
# '\nhouses sold with an over quality of less than 2 sold for less then 100000$ while houses with Kitchens above grade 0,2 and 3 did not sell houses above 200000$ with a shorter box plot indicating there was a smaller spread, houses did not sell well above the average price also indicated by having no outliers.\nhouses sold with an overall quality rating of 3 to 8 and houses with Kitchens above grade 1 increase in spread indicating houses were sold with a variability in price. although the skewness appears to be even, the sale price is evenly distributed.\nhouses with outliers show that some houses were sold way above the maximum value of the house indicating a larger profit margin, this is more common to houses with an overall quality of 8 and above and Kitchens above grade 0 and 3.\nhouses with an overall quality of 9 have a negaitve skewness indicating that the average selling price is much lower than the average while the houses with an overall quality of 10  have a possitive skewn
# ...

# %%
#openind the 'data/data_description.txt' file to use in comparison 
with open('data/data_description.txt', 'r') as file:
        data_description = file.read()

print(data_description)
# Out:
# MSSubClass: Identifies the type of dwelling involved in the sale.
#
#         20	1-STORY 1946 & NEWER ALL STYLES
#         30	1-STORY 1945 & OLDER
#         40	1-STORY W/FINISHED ATTIC ALL AGES
#         45	1-1/2 STORY - UNFINISHED ALL AGES
#         50	1-1/2 STORY FINISHED ALL AGES
#         60	2-STORY 1946 & NEWER
#         70	2-STORY 1945 & OLDER
#         75	2-1/2 STORY ALL AGES
#         80	SPLIT OR MULTI-LEVEL
#         85	SPLIT FOYER
#         90	DUPLEX - ALL STYLES AND AGES
#        120	1-STORY PUD (Planned Unit Development) - 1946 & NEWER
#        150	1-1/2 STORY PUD - ALL AGES
#        160	2-STORY PUD - 1946 & NEWER
#        180	PUD - MULTILEVEL - INCL SPLIT LEV/FOYER
#        190	2 FAMILY CONVERSION - ALL STYLES AND AGES
#
# MSZoning: Identifies the general zoning classification of the sale.
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
# ...

# %% [markdown]
# ## 5. Engineer and Explore a New Feature
#
# Here the code is written for you, all you need to do is interpret it.
#
# We note that the data spans across several years of sales:

# %%
# Run this cell without changes
df["YrSold"].value_counts().sort_index()
# Out:
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: YrSold, dtype: int64

# %% [markdown]
# Maybe we can learn something interesting from the age of the home when it was sold. This uses information from the `YrBuilt` and `YrSold` columns, but represents a truly distinct feature.

# %%
# Run this cell without changes

# Make a new column, Age
df["Age"] = df["YrSold"] - df["YearBuilt"]

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Plot Age vs. SalePrice
ax.scatter(df["Age"], df["SalePrice"], alpha=0.3, color="green")
ax.set_title("Home Age vs. Sale Price")
ax.set_xlabel("Age of Home at Time of Sale")
ax.set_ylabel("Sale Price");

# %% [markdown]
# Interpret this plot below:

# %%
# Replace None with appropriate text
"""
The scatter plot above shows there seems to be a coorelation between age of the house and the sale price, the newer the house the higher the sales price.
Although there is a coorelation does not mean there is a causeation because there are many factors that could affect the price of a house when being sold eg(condition of the house, Slope of property and rooms above grade),
for example a  house built roughly 120 years ago sold for 500000$.It seems that a magority fo the home owners sold their house between 0 to 60 years. The highest selling house was less than 20years old and sold for more than 700000$,there is no house sold that is greater than 140 years 
"""
# Out:
# '\nThe scatter plot above shows there seems to be a coorelation between age of the house and the sale price, the newer the house the higher the sales price.\nAlthough there is a coorelation does not mean there is a causeation because there are many factors that could affect the price of a house when being sold eg(condition of the house, Slope of property and rooms above grade),\nfor example a  house built roughly 120 years ago sold for 500000$.It seems that a magority fo the home owners sold their house between 0 to 60 years. The highest selling house was less than 20years old and sold for more than 700000$,there is no house sold that is greater than 140 years \n'

# %% [markdown]
# ## Summary
#
# Congratulations, you've completed an exploratory data analysis of a popular dataset. You saw how to inspect the distributions of individual columns, subsets of columns, correlations, and new engineered features.

# %% [markdown]
# ## [here is a link to my data presentation]
# https://docs.google.com/presentation/d/1OtHiJxIHKC0aTou50JFFVeLEqkS1H2FgowRHkKrHM_w/edit?usp=sharing
